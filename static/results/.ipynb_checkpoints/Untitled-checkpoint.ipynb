# %%
import numpy as np

# %%
data = np.load('np_pred.npy')

# %%
data
# Out:
# array([[ 5.9228854, 10.272971 ,  4.4664702, ...,  5.997259 ,  6.1381116,
#          6.0366173],
#        [ 5.374395 ,  7.7921453,  4.4225616, ...,  5.3883295,  5.58727  ,
#          5.3898396],
#        [ 4.9307427, 12.683672 ,  4.3999276, ...,  5.026502 ,  5.0582333,
#          4.8884935],
#        ...,
#        [ 4.6753798,  9.279388 ,  4.461059 , ...,  4.3110495,  4.1845427,
#          4.178996 ],
#        [ 4.6054697,  7.1026874,  4.4139934, ...,  4.761072 ,  4.257115 ,
#          4.2487254],
#        [ 6.0582123, 20.479744 ,  4.3832955, ...,  5.30801  ,  5.5761857,
#          5.0723968]], dtype=float32)

# %%
count = 0
for i in data:
    if count==0:
        print("data : {}\n".format(i))
        quant = np.percentile(i,[1,25,50,75,99])
    print(quant)
# Out:
# data : [ 5.9228854 10.272971   4.4664702 10.937811   6.4474196  5.760752
#   5.992672   7.005367   5.8979735  7.447156   6.3693104 13.608418
#   7.03952    5.3653846  4.4634504  7.216509   5.5745616  6.0892563
#   7.0969076  8.1959915  9.678947   7.3083367  5.346509   7.683918
#   7.2872095  6.281875   5.5663104  5.326085  10.054013   6.4929132
#   6.71038    6.3252487  6.8944864  5.1463923  6.6859283  5.492359
#   6.5757375  7.3456106  5.9703355  5.7875614  6.2281055  5.976979
#   5.814138   6.296736   5.5465426  8.916616   7.827583   7.832894
#   7.6478796 28.291552   7.005217   5.723675   9.986825   9.890231
#  17.795143   5.8789086  5.0622387  5.224515   4.0806704 57.902718
#   7.2590733  4.5706882  4.981642   4.9867396  6.284498   4.7546606
#   8.535443   7.4156537  6.0735064  7.798815   5.9199204  6.324559
#   7.9863024  6.5182185  5.656887   7.1812606 14.831568   5.551086
#   5.1828547  6.6175327  9.8288965  5.3149714  5.376073   8.268405
# ...
